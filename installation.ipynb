# %%
# !pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Requirement already satisfied: torch in ./venv/lib/python3.10/site-packages (2.9.1+cu126)
# Requirement already satisfied: torchvision in ./venv/lib/python3.10/site-packages (0.24.1+cu126)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in ./venv/lib/python3.10/site-packages (from torch) (10.3.7.77)
# Requirement already satisfied: sympy>=1.13.3 in ./venv/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in ./venv/lib/python3.10/site-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in ./venv/lib/python3.10/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in ./venv/lib/python3.10/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in ./venv/lib/python3.10/site-packages (from torch) (12.5.4.2)
# Requirement already satisfied: filelock in ./venv/lib/python3.10/site-packages (from torch) (3.19.1)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in ./venv/lib/python3.10/site-packages (from torch) (1.11.1.6)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in ./venv/lib/python3.10/site-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in ./venv/lib/python3.10/site-packages (from torch) (12.6.4.1)
# Requirement already satisfied: fsspec>=0.8.5 in ./venv/lib/python3.10/site-packages (from torch) (2025.9.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./venv/lib/python3.10/site-packages (from torch) (4.15.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in ./venv/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in ./venv/lib/python3.10/site-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in ./venv/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in ./venv/lib/python3.10/site-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in ./venv/lib/python3.10/site-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in ./venv/lib/python3.10/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in ./venv/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: triton==3.5.1 in ./venv/lib/python3.10/site-packages (from torch) (3.5.1)
# Requirement already satisfied: networkx>=2.5.1 in ./venv/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./venv/lib/python3.10/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: numpy in ./venv/lib/python3.10/site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)

# %%
# %pip install pybind11 ninja
# Out:
# Requirement already satisfied: pybind11 in ./venv/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: ninja in ./venv/lib/python3.10/site-packages (1.13.0)

# %%
# %pip install numpy matplotlib
# Out:
# Requirement already satisfied: numpy in ./venv/lib/python3.10/site-packages (2.2.6)
# Collecting matplotlib
#   Using cached matplotlib-3.10.7-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Collecting pyparsing>=3
#   Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.61.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 17.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pillow>=8 in ./venv/lib/python3.10/site-packages (from matplotlib) (11.3.0)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.10/site-packages (from matplotlib) (25.0)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.61.0 kiwisolver-1.4.9 matplotlib-3.10.7 pyparsing-3.2.5

# %%
# %pip install pytest
# Out:
# Collecting pytest
#   Using cached pytest-9.0.1-py3-none-any.whl (373 kB)
# Collecting pluggy<2,>=1.5
#   Using cached pluggy-1.6.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: pygments>=2.7.2 in ./venv/lib/python3.10/site-packages (from pytest) (2.19.2)
# Requirement already satisfied: exceptiongroup>=1 in ./venv/lib/python3.10/site-packages (from pytest) (1.3.1)
# Requirement already satisfied: packaging>=22 in ./venv/lib/python3.10/site-packages (from pytest) (25.0)
# Collecting tomli>=1
#   Using cached tomli-2.3.0-py3-none-any.whl (14 kB)
# Collecting iniconfig>=1.0.1
#   Using cached iniconfig-2.3.0-py3-none-any.whl (7.5 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in ./venv/lib/python3.10/site-packages (from exceptiongroup>=1->pytest) (4.15.0)
# Installing collected packages: tomli, pluggy, iniconfig, pytest
# Successfully installed iniconfig-2.3.0 pluggy-1.6.0 pytest-9.0.1 tomli-2.3.0

# %%
# %pip install pyvista
# Out:
# Collecting pyvista
#   Using cached pyvista-0.46.4-py3-none-any.whl (2.4 MB)
# Requirement already satisfied: typing-extensions>=4.10 in ./venv/lib/python3.10/site-packages (from pyvista) (4.15.0)
# Collecting pooch
#   Using cached pooch-1.8.2-py3-none-any.whl (64 kB)
# Collecting scooby>=0.5.1
#   Using cached scooby-0.11.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: matplotlib>=3.0.1 in ./venv/lib/python3.10/site-packages (from pyvista) (3.10.7)
# Collecting vtk<9.6.0
#   Using cached vtk-9.5.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (112.2 MB)
# Requirement already satisfied: pillow in ./venv/lib/python3.10/site-packages (from pyvista) (11.3.0)
# Requirement already satisfied: numpy>=1.21.0 in ./venv/lib/python3.10/site-packages (from pyvista) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista) (3.2.5)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista) (4.61.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista) (25.0)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista) (0.12.1)
# Requirement already satisfied: platformdirs>=2.5.0 in ./venv/lib/python3.10/site-packages (from pooch->pyvista) (4.5.0)
# Collecting requests>=2.19.0
#   Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.1->pyvista) (1.17.0)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.11-py3-none-any.whl (71 kB)
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Installing collected packages: urllib3, scooby, idna, charset_normalizer, certifi, requests, vtk, pooch, pyvista
# Successfully installed certifi-2025.11.12 charset_normalizer-3.4.4 idna-3.11 pooch-1.8.2 pyvista-0.46.4 requests-2.32.5 scooby-0.11.0 urllib3-2.5.0 vtk-9.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -c "import pyvista as pv; print(pv.Report())"
# Out:
# --------------------------------------------------------------------------------
#   Date: Sun Nov 30 15:48:48 2025 UTC
#
#                 OS : Linux (Ubuntu 22.04)
#             CPU(s) : 20
#            Machine : x86_64
#       Architecture : 64bit
#                RAM : 62.4 GiB
#        Environment : Python
#        File system : ext4
#         GPU Vendor : NVIDIA Corporation
#       GPU Renderer : NVIDIA GeForce RTX 4060 Laptop GPU/PCIe/SSE2
#        GPU Version : 4.5.0 NVIDIA 580.95.05
#      Render Window : vtkXOpenGLRenderWindow
#   MathText Support : True
#
#   Python 3.10.12 (main, Nov  4 2025, 08:48:33) [GCC 11.4.0]
#
#            pyvista : 0.46.4
#                vtk : 9.5.2
#              numpy : 2.2.6
#         matplotlib : 3.10.7
#             scooby : 0.11.0
#              pooch : 1.8.2
#             pillow : 11.3.0
#            IPython : 8.37.0
#       nest_asyncio : 1.6.0
# --------------------------------------------------------------------------------

# %%
# %pip install pyside6 pyvistaqt
# Out:
# Requirement already satisfied: pyside6 in ./venv/lib/python3.10/site-packages (6.10.1)
# Collecting pyvistaqt
#   Using cached pyvistaqt-0.11.3-py3-none-any.whl (131 kB)
# Requirement already satisfied: shiboken6==6.10.1 in ./venv/lib/python3.10/site-packages (from pyside6) (6.10.1)
# Requirement already satisfied: PySide6_Addons==6.10.1 in ./venv/lib/python3.10/site-packages (from pyside6) (6.10.1)
# Requirement already satisfied: PySide6_Essentials==6.10.1 in ./venv/lib/python3.10/site-packages (from pyside6) (6.10.1)
# Collecting QtPy>=1.9.0
#   Using cached QtPy-2.4.3-py3-none-any.whl (95 kB)
# Requirement already satisfied: pyvista>=0.32.0 in ./venv/lib/python3.10/site-packages (from pyvistaqt) (0.46.4)
# Requirement already satisfied: vtk!=9.4.0 in ./venv/lib/python3.10/site-packages (from pyvista>=0.32.0->pyvistaqt) (9.5.2)
# Requirement already satisfied: pillow in ./venv/lib/python3.10/site-packages (from pyvista>=0.32.0->pyvistaqt) (11.3.0)
# Requirement already satisfied: matplotlib>=3.0.1 in ./venv/lib/python3.10/site-packages (from pyvista>=0.32.0->pyvistaqt) (3.10.7)
# Requirement already satisfied: pooch in ./venv/lib/python3.10/site-packages (from pyvista>=0.32.0->pyvistaqt) (1.8.2)
# Requirement already satisfied: numpy>=1.21.0 in ./venv/lib/python3.10/site-packages (from pyvista>=0.32.0->pyvistaqt) (2.2.6)
# Requirement already satisfied: typing-extensions>=4.10 in ./venv/lib/python3.10/site-packages (from pyvista>=0.32.0->pyvistaqt) (4.15.0)
# Requirement already satisfied: scooby>=0.5.1 in ./venv/lib/python3.10/site-packages (from pyvista>=0.32.0->pyvistaqt) (0.11.0)
# Requirement already satisfied: packaging in ./venv/lib/python3.10/site-packages (from QtPy>=1.9.0->pyvistaqt) (25.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista>=0.32.0->pyvistaqt) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=3 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista>=0.32.0->pyvistaqt) (3.2.5)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista>=0.32.0->pyvistaqt) (4.61.0)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista>=0.32.0->pyvistaqt) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista>=0.32.0->pyvistaqt) (1.3.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista>=0.32.0->pyvistaqt) (1.4.9)
# Requirement already satisfied: platformdirs>=2.5.0 in ./venv/lib/python3.10/site-packages (from pooch->pyvista>=0.32.0->pyvistaqt) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in ./venv/lib/python3.10/site-packages (from pooch->pyvista>=0.32.0->pyvistaqt) (2.32.5)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.1->pyvista>=0.32.0->pyvistaqt) (1.17.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.10/site-packages (from requests>=2.19.0->pooch->pyvista>=0.32.0->pyvistaqt) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.10/site-packages (from requests>=2.19.0->pooch->pyvista>=0.32.0->pyvistaqt) (2025.11.12)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.10/site-packages (from requests>=2.19.0->pooch->pyvista>=0.32.0->pyvistaqt) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.10/site-packages (from requests>=2.19.0->pooch->pyvista>=0.32.0->pyvistaqt) (3.4.4)
# Installing collected packages: QtPy, pyvistaqt
# Successfully installed QtPy-2.4.3 pyvistaqt-0.11.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import PySide6.QtCore

# Prints PySide6 version
print(PySide6.__version__)

# Prints the Qt version used to compile PySide6
print(PySide6.QtCore.__version__)
# Out:
# 6.10.1
# 6.10.1

# %%
# !sudo apt install libxcb-cursor0 libx11-xcb1 libxcb-keysyms1 libxcb-xinerama0

# %%
# !pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Requirement already satisfied: torch in ./venv/lib/python3.10/site-packages (2.9.1+cu126)
# Requirement already satisfied: torchvision in ./venv/lib/python3.10/site-packages (0.24.1+cu126)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in ./venv/lib/python3.10/site-packages (from torch) (3.3.20)
# Requirement already satisfied: filelock in ./venv/lib/python3.10/site-packages (from torch) (3.19.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in ./venv/lib/python3.10/site-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in ./venv/lib/python3.10/site-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in ./venv/lib/python3.10/site-packages (from torch) (12.6.85)
# Requirement already satisfied: triton==3.5.1 in ./venv/lib/python3.10/site-packages (from torch) (3.5.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in ./venv/lib/python3.10/site-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in ./venv/lib/python3.10/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./venv/lib/python3.10/site-packages (from torch) (4.15.0)
# Requirement already satisfied: networkx>=2.5.1 in ./venv/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in ./venv/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in ./venv/lib/python3.10/site-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in ./venv/lib/python3.10/site-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in ./venv/lib/python3.10/site-packages (from torch) (12.6.4.1)
# Requirement already satisfied: fsspec>=0.8.5 in ./venv/lib/python3.10/site-packages (from torch) (2025.9.0)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in ./venv/lib/python3.10/site-packages (from torch) (1.11.1.6)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in ./venv/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in ./venv/lib/python3.10/site-packages (from torch) (0.7.1)
# Requirement already satisfied: sympy>=1.13.3 in ./venv/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in ./venv/lib/python3.10/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in ./venv/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: numpy in ./venv/lib/python3.10/site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./venv/lib/python3.10/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)

# %%
# %pip install h5py
# Out:
# Collecting h5py
#   Downloading h5py-3.15.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 7.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.21.2 in ./venv/lib/python3.10/site-packages (from h5py) (2.2.6)
# Installing collected packages: h5py
# Successfully installed h5py-3.15.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install tqdm
# Out:
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.
